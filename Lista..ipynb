# %% [markdown]
# <a href="https://colab.research.google.com/github/TEDZ1N/PROVA-A1/blob/main/Lista..ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
animais = ["gato", "cachorro", "pássaro"]

# O primeiro item (índice 0)
primeiro = animais[0]
print(f"O primeiro animal é: {primeiro}")
# Saída: O primeiro animal é: gato

# O terceiro item (índice 2)
terceiro = animais[2]
print(f"O terceiro animal é: {terceiro}")
# Saída: O terceiro animal é: pássaro
# Out:
# O primeiro animal é: gato
# O terceiro animal é: pássaro
