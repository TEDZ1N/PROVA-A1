# %% [markdown]
# <a href="https://colab.research.google.com/github/TEDZ1N/PROVA-A1/blob/main/Dici%C3%B3narios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno = {}  # cria o dicionário vazio

# coleta os dados
aluno["nome"] = input("Digite o nome do aluno: ")
aluno["idade"] = int(input("Digite a idade do aluno: "))
aluno["curso"] = input("Digite o curso do aluno: ")

# exibe usando o dicionário
print("\n--- Dados do Aluno ---")
print("Nome:", aluno["nome"])
print("Idade:", aluno["idade"])
print("Curso:", aluno["curso"])
# Out:
# Digite o nome do aluno: joseias
# Digite a idade do aluno: 68
# Digite o curso do aluno: engenharia
#
# --- Dados do Aluno ---
# Nome: joseias
# Idade: 68
# Curso: engenharia
